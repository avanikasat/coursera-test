# %% [markdown]
# Code of Academic Integrity
#
# I, Avani Kasat affirm that
#
# This work is my own original work and is not a borrowed work,either from other students or from assignments for other courses.
#
# I have not given or received any unauthorized help on this assignment.
#
# This submission is free from
#
# – Plagiarism
#
# – Fabrication of facts
#
# – Unauthorized assistance
#
# – Collusion
#
# This submission gives proper credit to sources and references,acknowledges the contributions and ideas of others relevant tothis academic work.
#
# This submission was prepared by me fully adhering to the rulesthat govern this assignment regarding resource material, electronic aids, copying, collaborating with others, or engaging in any other behavior that subverts the purpose of the assignmentand the directions of the teacher.

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Q1. DRAW 3 PLOTS USING MATPLOTLIB

# %% [markdown]
# part 1.

# %%
plt.figure(figsize=(8,8))
x = [0, 200, 0, 100, 200]
y = [0, 100, 200, 0, 200]
plt.plot(x, y, color='orange' , marker='o', markersize=20, linestyle='-', linewidth=2)
x = [0, 100, 200, 0, 200]
y = [0, 200, 0, 100, 200]
plt.plot(x, y, color='blue' , marker='o', markersize=20, linestyle='-', linewidth=2)
plt.plot(100,100, color='blue' , marker='o',markersize=20)

# %% [markdown]
# part 2.

# %%
plt.figure(figsize=(8,8))
x1 = [0,5,17,20,30,40,60 ,70]
y1 = [0,5,10,17,25,38,50,64]
# plotting the line 1 points 
plt.plot(x1, y1,color='green', label ='tv', marker='o', markersize=10, linestyle='--')
x2 = [0,19,37,45,60,70,80 ,90]
y2 = [0,5,10,17,25,38,50,64]
# plotting the line 1 points 

plt.plot(x2, y2, label = 'smartphone', color='yellow',marker='s', markersize=10, linestyle='-')
plt.xlabel('medium')
plt.ylabel('sales')
plt.title('Advertisement Effect On sales')
# Out:
# Text(0.5, 1.0, 'Advertisement Effect On sales')

# %% [markdown]
# part 3.

# %%
from matplotlib.patches import Polygon
circle1 = plt.Circle((0.2, 0.2), 0.2, color='orange')
circle2 = plt.Circle((0.5, 0.5), 0.2, color='yellow')
circle3 = plt.Circle((0.8, 0.2), 0.2, color='red', )
fig, ax = plt.subplots()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
pts = np.array([[0.5,0.8], [1,1], [0,1]])
p = Polygon(pts, closed=False)
ax.add_patch(p)

# %% [markdown]
# Q2. Draw a rough sketch of the figure that corresponds to the equation
#
# y^2=4*x^3
#
# using plt.scatter alone

# %%
plt.figure(figsize=(13,8))
import math 
for x in range(500):
  y=math.sqrt(4*x*x*x)
  
  plt.title("Scatter Plot for eq: y^2=4*x^3", fontsize = 13)
  plt.scatter(x, y,color='red')

# %% [markdown]
# Q3. Take a dataset which has atleast one column with categorical values. Perform all the operations of matpotlib discussed in the lab session such that
# your output should have three different line plots, three different bar plots,
# three different histograms, two scatter plot (in ’ggplot’ style), two seabornscatterplot and two pie-chart. In total, you have to give 15 plots. All the
# plots of same type, should have different arguments.

# %%
df=pd.read_csv('used_cars.csv')
df.head()
# Out:
#   manufacturer_name model_name  ... price_usd is_exchangeable
# 0            Subaru    Outback  ...  10900.00           False
# 1            Subaru    Outback  ...   5000.00            True
# 2            Subaru   Forester  ...   2800.00            True
# 3            Subaru    Impreza  ...   9999.00            True
# 4            Subaru     Legacy  ...   2134.11            True
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# manufacturer_name    0
# model_name           0
# transmission         0
# color                0
# odometer_value       0
# year_produced        0
# engine_fuel          0
# engine_has_gas       0
# engine_type          0
# engine_capacity      0
# body_type            0
# has_warranty         0
# state                0
# drivetrain           0
# price_usd            0
# is_exchangeable      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# manufacturer_name    500
# model_name           500
# transmission         500
# color                500
# odometer_value       500
# year_produced        500
# engine_fuel          500
# engine_has_gas       500
# engine_type          500
# engine_capacity      500
# body_type            500
# has_warranty         500
# state                500
# drivetrain           500
# price_usd            500
# is_exchangeable      500
# dtype: int64

# %%
plt.figure(figsize=(18,8))
plt.plot(df['engine_type'],color="red")
plt.title("Age vs Rows Line Plot", fontsize = 13)
plt.xlabel("Row Indexes")
plt.ylabel("Engine Type")
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.plot(df['color'],color="red")
plt.title("Color vs Rows Line Plot", fontsize = 13)
plt.xlabel("Row Indexes")
plt.ylabel("Color")
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.plot(df['body_type'],color="red")
plt.title("Body Type vs Rows Line Plot", fontsize = 13)
plt.xlabel("Row Indexes")
plt.ylabel("Body Type")
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.bar(x = df['model_name'], height = df['color'], width = 1.5, color="red")
plt.title("Color-Model name Plot", fontsize = 10)
plt.xlabel("model name")
plt.ylabel("color")
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.bar(x = df['engine_capacity'], height = df['price_usd'], width = 1.5, color="red")
plt.title("Price-Engine_capacity Plot", fontsize = 10)
plt.xlabel("Engine Capacity")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(18,9))
plt.bar(x = df['year_produced'], height = df['odometer_value'], width = 1.5, color="red")
plt.title("Odometer_Value-Engine Produced Plot", fontsize = 10)
plt.xlabel("Year of Production")
plt.ylabel("Odometer Value")
plt.show()

# %%
plt.figure(figsize=(13,9))
plt.hist(df['color'], bins = 10, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("color")
plt.ylabel("Frequency in Range")
plt.show()

# %%
plt.figure(figsize=(13,9))
plt.hist(df['model_name'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("model_name")
plt.ylabel("Frequency in Range")
plt.show()

# %%
plt.figure(figsize=(13,9))
plt.hist(df['body_type'], bins = 10, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("body_type")
plt.ylabel("Frequency in Range")
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(15,10))
plt.scatter(x = df['model_name'], y =df['odometer_value'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("Model Nmae")
plt.ylabel("Odometer")
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(15,10))
plt.scatter(x = df['year_produced'], y =df['odometer_value'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("Year of Production")
plt.ylabel("Odometer Value")
plt.show()

# %%
#ggplot
plt.style.use('ggplot')
plt.figure(figsize=(13,8))
plt.scatter(x = df['year_produced'], y = df['odometer_value'], color = 'red', marker='^', label = 'odometer value')
plt.scatter(x = df['year_produced'], y = df['price_usd'], color = 'blue', marker = 'o', label = 'price in usd')
plt.title("Scatter Plot", fontsize = 10)
plt.xlabel("year of production")
plt.ylabel("odometer value/price_usd")
plt.legend()
plt.show()

# %%
#ggplot
plt.style.use('ggplot')
plt.figure(figsize=(13,8))
plt.scatter(x = df['price_usd'], y = df['engine_capacity'], color = 'red', marker='^', label = 'engine capacity')
plt.scatter(x = df['price_usd'], y = df['color'], color = 'blue', marker = 'o', label = 'color')
plt.title("Scatter Plot", fontsize = 10)
plt.xlabel("price")
plt.ylabel("color/engine_capacity")
plt.legend()
plt.show()

# %%
#finding unique names of the model
df['model_name'].unique()
# Out:
# array(['Outback', 'Forester', 'Impreza', 'Legacy', 'Tribeca', 'Justy',
#        'XV', 'Leone', 'WRX', 'Libero', 'Vesta', 'Largus', 'XRAY', '4x4',
#        'Priora', 'Granta', '111', 'Kalina', '112', '110', 'Dart',
#        'Stratus', 'Grand Caravan', 'Caravan', 'Intrepid', 'Caliber',
#        'Neon', 'Magnum', 'Avenger', 'Journey', 'Durango', 'Van'],
#       dtype=object)

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'price_usd', y = 'odometer_value', data = df, hue = 'model_name', palette='plasma')
plt.show()

# %%
#finding unique names of the transmission
df['transmission'].unique()
# Out:
# array(['automatic', 'mechanical'], dtype=object)

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'price_usd', y = 'color', data = df, hue = 'transmission', palette='plasma')
plt.show()

# %%
df['model_name'].value_counts()
# Out:
# Forester         80
# Outback          67
# Legacy           64
# Vesta            53
# Impreza          42
# Caravan          20
# Largus           20
# Tribeca          19
# XRAY             16
# Granta           15
# 4x4              14
# Priora           13
# Stratus           9
# Caliber           9
# XV                9
# Kalina            8
# Grand Caravan     7
# Intrepid          6
# Justy             6
# 111               4
# Neon              3
# 110               2
# Journey           2
# Magnum            2
# Dart              2
# Libero            2
# WRX               1
# Durango           1
# Van               1
# Leone             1
# 112               1
# Avenger           1
# Name: model_name, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(df['transmission'].value_counts(), autopct='%0.2f%%', labels = df['transmission'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %%
plt.figure(figsize=(8,8))
plt.pie(df['color'].value_counts(), autopct='%0.2f%%', labels = df['color'].unique())
plt.show() 
plt.savefig('Pie1.jpg')

# %% [markdown]
# Q4. Generate a dataset with make−regression function and create a dataframe.
# Output 5 different dataframes by changing the parameters of make−regression
# function. Plot one scatter-plot, one bar plot, one histogram, one seabornscatter plot and one pie-chart for each of the datafram

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_regression

# %%
data1=make_regression(n_samples=100, n_features=10, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)

# %%
data1
# Out:
# (array([[-0.59645557, -1.3000352 ,  0.43916229, -0.50939438,  0.94633682,
#           1.90525724, -1.15363788, -0.74491251,  0.28154548,  0.15605632],
#         [ 0.84413563, -0.01881286,  0.61641437, -0.29505802,  0.51320676,
#          -1.38841271, -1.1752378 , -0.39640871,  0.91057131, -1.26195025],
#         [ 1.98063404, -2.05833327, -0.33405469,  0.12050965, -0.31308761,
#           0.97793773,  0.1176951 ,  0.63624961,  1.62674996,  0.02861533],
#         [-0.73386294, -0.40566322, -0.52466518, -0.11618836,  1.71779477,
#          -2.32159144,  0.74519262,  0.17463599,  0.37412891,  0.2666946 ],
#         [-0.81929971, -0.97687669, -2.05542208, -0.35906254, -2.46647696,
#           1.07052755,  1.29530479, -0.26201179, -0.34385943,  0.18428779],
#         [-1.22846552, -1.45930936,  0.1142784 ,  0.67294463,  1.19713712,
#          -1.32354506, -0.12033797, -0.54140987, -1.66779778, -0.95982179],
#         [ 0.17717994,  1.36875476, -0.04971424,  0.6996669 , -0.70482343,
# ...

# %%
df1 = pd.DataFrame(data1[0],columns=['x'+str(i) for i in range(0,10)])
df1
# Out:
#           x0        x1        x2  ...        x7        x8        x9
# 0  -0.596456 -1.300035  0.439162  ... -0.744913  0.281545  0.156056
# 1   0.844136 -0.018813  0.616414  ... -0.396409  0.910571 -1.261950
# 2   1.980634 -2.058333 -0.334055  ...  0.636250  1.626750  0.028615
# 3  -0.733863 -0.405663 -0.524665  ...  0.174636  0.374129  0.266695
# 4  -0.819300 -0.976877 -2.055422  ... -0.262012 -0.343859  0.184288
# ..       ...       ...       ...  ...       ...       ...       ...
# 95  0.384540  0.648367 -0.289233  ... -0.161332  0.488337 -0.432726
# 96  0.649560 -1.961973 -0.746318  ... -0.857954  0.423776  1.939339
# 97 -1.733112  0.373119  0.538433  ... -0.238357 -0.944214 -0.079566
# 98 -0.942394 -0.457010 -0.067359  ...  0.942087  1.213699 -1.766234
# 99  0.650960 -0.258999 -0.405305  ...  1.357644  0.222272  1.019357
#
# [100 rows x 10 columns]

# %%
#Scatter Plot
plt.figure(figsize=(13,8))
plt.scatter(x =df1['x1'], y = df1['x2'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#barplot
plt.figure(figsize=(15,9))
plt.bar(x = df1['x1'], height =df1['x3'], width = 1.5, color="red")
plt.title("x1-x3 Plot", fontsize = 10)
plt.xlabel("x1")
plt.ylabel("x3")
plt.show()

# %%
#histogram
plt.figure(figsize=(13,9))
plt.hist(df1['x4'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("x4 Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'x2', y = 'x6', data = df1, hue = 'x1', palette='plasma')
plt.show()

# %%
#piechart
plt.figure(figsize=(8,8))
plt.pie(df1['x3'].value_counts(), autopct='%0.2f%%', labels = df1['x3'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %%
data2=make_regression(n_samples=50, n_features=5, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)
data2
# Out:
# (array([[ 0.11201149, -2.14652439, -1.02703935, -1.14064332, -2.89847582],
#         [-0.49850734, -0.89576821,  0.81465766,  0.84996372,  0.47247342],
#         [-0.5363213 , -0.21360423,  0.53483759,  0.03098567, -0.39627596],
#         [-1.55017291, -0.77598869,  0.86354927, -0.00763091, -1.45444465],
#         [-2.61523899,  2.64232706, -1.09897321, -0.27460526, -1.41706916],
#         [-2.20560048,  1.99556127,  0.58727437, -1.50585425,  0.0133156 ],
#         [-1.35382002,  1.09031313, -0.49016689, -1.5441764 , -0.40108112],
#         [ 1.19437095, -0.10203798, -0.89664448,  0.47480344,  0.89441297],
#         [ 0.91946502,  0.43306734, -0.01213383,  0.42563728, -0.47066744],
#         [-1.42076569, -1.87882265, -0.82327991,  2.03379285,  1.74055315],
#         [-2.03159819,  0.63418533, -0.09347052,  0.16470947, -0.53109184],
#         [-1.12736245, -1.13372268,  1.26092004, -0.0847065 ,  0.21947096],
# ...

# %%
df2 = pd.DataFrame(data2[0],columns=['x'+str(i) for i in range(0,5)])
df2
# Out:
#           x0        x1        x2        x3        x4
# 0   0.112011 -2.146524 -1.027039 -1.140643 -2.898476
# 1  -0.498507 -0.895768  0.814658  0.849964  0.472473
# 2  -0.536321 -0.213604  0.534838  0.030986 -0.396276
# 3  -1.550173 -0.775989  0.863549 -0.007631 -1.454445
# 4  -2.615239  2.642327 -1.098973 -0.274605 -1.417069
# 5  -2.205600  1.995561  0.587274 -1.505854  0.013316
# 6  -1.353820  1.090313 -0.490167 -1.544176 -0.401081
# 7   1.194371 -0.102038 -0.896644  0.474803  0.894413
# 8   0.919465  0.433067 -0.012134  0.425637 -0.470667
# 9  -1.420766 -1.878823 -0.823280  2.033793  1.740553
# 10 -2.031598  0.634185 -0.093471  0.164709 -0.531092
# 11 -1.127362 -1.133723  1.260920 -0.084706  0.219471
# 12 -0.512732  0.735157 -0.720126  0.327295  0.957245
# 13 -0.636397 -1.061333 -0.112320 -1.691941  0.869224
# 14 -1.457265 -1.752378 -0.549913 -0.222329  0.162514
# 15 -1.741544 -0.700952 -1.100486 -0.483665 -1.703425
# 16  0.229644 -1.123936  0.292712  0.529742 -0.368596
# ...

# %%
#Scatter Plot
plt.figure(figsize=(13,8))
plt.scatter(x =df2['x1'], y = df2['x2'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#barplot
plt.figure(figsize=(15,9))
plt.bar(x = df2['x2'], height =df2['x3'], width = 1.5, color="red")
plt.title("x1-x3 Plot", fontsize = 10)
plt.xlabel("x1")
plt.ylabel("x3")
plt.show()

# %%
#histogram
plt.figure(figsize=(13,9))
plt.hist(df2['x4'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("x4 Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'x2', y = 'x3', data = df2, hue = 'x1', palette='plasma')
plt.show()

# %%
#piechart
plt.figure(figsize=(8,8))
plt.pie(df2['x3'].value_counts(), autopct='%0.2f%%', labels = df2['x3'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %%
data3=make_regression(n_samples=30, n_features=3, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)
data3
# Out:
# (array([[ 0.71196664,  1.4269241 , -1.16669083],
#         [-0.09364426,  0.27128449, -0.58835524],
#         [-0.5100201 ,  0.32044589,  1.48173768],
#         [-1.20363987, -1.16021146,  0.62348623],
#         [-1.0789184 , -0.19892167, -0.24341085],
#         [ 0.31097672,  0.75896039,  0.84732028],
#         [ 0.81732827, -0.15559813, -0.21203813],
#         [-0.15930793, -1.10068094,  0.59612336],
#         [-1.79542054, -0.13441855,  0.44539337],
#         [-0.24783986, -2.20680018,  0.48710107],
#         [ 0.98831969,  2.08635349,  1.21030956],
#         [ 2.27186307,  1.80990083, -0.00676533],
#         [ 0.98114391, -1.27989083,  0.0797051 ],
#         [-0.16258483, -0.49965211,  0.14500369],
#         [ 1.27508396,  1.26164496,  0.85636345],
#         [-0.52155446, -0.68621409, -0.58959989],
#         [-0.2954409 , -0.12327674,  0.27704208],
#         [-0.73328144,  0.1401647 , -0.06936786],
#         [-0.37626325,  1.51241012,  1.31217673],
# ...

# %%
df3 = pd.DataFrame(data3[0],columns=['x'+str(i) for i in range(0,3)])
df3
# Out:
#           x0        x1        x2
# 0   0.711967  1.426924 -1.166691
# 1  -0.093644  0.271284 -0.588355
# 2  -0.510020  0.320446  1.481738
# 3  -1.203640 -1.160211  0.623486
# 4  -1.078918 -0.198922 -0.243411
# 5   0.310977  0.758960  0.847320
# 6   0.817328 -0.155598 -0.212038
# 7  -0.159308 -1.100681  0.596123
# 8  -1.795421 -0.134419  0.445393
# 9  -0.247840 -2.206800  0.487101
# 10  0.988320  2.086353  1.210310
# 11  2.271863  1.809901 -0.006765
# 12  0.981144 -1.279891  0.079705
# 13 -0.162585 -0.499652  0.145004
# 14  1.275084  1.261645  0.856363
# 15 -0.521554 -0.686214 -0.589600
# 16 -0.295441 -0.123277  0.277042
# 17 -0.733281  0.140165 -0.069368
# 18 -0.376263  1.512410  1.312177
# 19 -1.054017 -0.201138 -0.271794
# 20  1.283164 -1.107171  0.462062
# 21  0.954923 -1.558796  1.786751
# 22 -2.350756 -0.824431  1.159841
# 23 -0.488018 -0.620173 -1.065183
# 24 -1.938530 -2.040715  1.247057
# 25  0.542282 -0.372171 -0.347162
# 26  0.912612  0.062325  0.752809
# ...

# %%
#Scatter Plot
plt.figure(figsize=(13,8))
plt.scatter(x =df3['x1'], y = df3['x2'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#barplot
plt.figure(figsize=(15,9))
plt.bar(x = df3['x1'], height =df3['x2'], width = 1.5, color="red")
plt.title("x1-x2 Plot", fontsize = 10)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#histogram
plt.figure(figsize=(13,9))
plt.hist(df3['x2'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("x3 Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'x0', y = 'x2', data = df3, hue = 'x1', palette='plasma')
plt.show()

# %%
#piechart
plt.figure(figsize=(8,8))
plt.pie(df3['x1'].value_counts(), autopct='%0.2f%%', labels = df3['x1'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %%
data4=make_regression(n_samples=45, n_features=8, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)
data4
# Out:
# (array([[-0.9703321 , -0.88026838,  1.24105963, -1.23055164, -1.34304469,
#           0.56523689,  0.01531148, -0.9261714 ],
#         [ 1.46775615, -0.45904154, -0.09239662,  0.53211041, -0.53923668,
#           0.59723134, -0.05321968, -0.97932736],
#         [ 0.99804728, -0.08409476, -0.74705272, -0.38789138, -0.65575202,
#           0.25265718, -0.72357797, -0.65020444],
#         [-0.46347443,  0.15165279, -0.28791779,  1.45411363,  0.64945091,
#          -0.67517439, -2.22953477,  2.27163858],
#         [ 1.44538727, -0.41205204,  0.49092609, -0.15523633,  1.86523429,
#           1.21086012, -0.58824366, -0.58717738],
#         [-0.39769839,  0.0844736 ,  2.00367372,  1.02216259,  0.02001232,
#           0.83049934,  1.34369292,  2.11637075],
#         [-0.88664072, -0.04507456, -0.65539956, -0.14706656, -1.67094698,
#          -0.11287331, -0.91235385, -0.61539811],
#         [ 0.06407528, -0.4368894 , -0.39297669, -0.22379808, -0.14507189,
# ...

# %%
df4 = pd.DataFrame(data4[0],columns=['x'+str(i) for i in range(0,8)])
df4
# Out:
#           x0        x1        x2  ...        x5        x6        x7
# 0  -0.970332 -0.880268  1.241060  ...  0.565237  0.015311 -0.926171
# 1   1.467756 -0.459042 -0.092397  ...  0.597231 -0.053220 -0.979327
# 2   0.998047 -0.084095 -0.747053  ...  0.252657 -0.723578 -0.650204
# 3  -0.463474  0.151653 -0.287918  ... -0.675174 -2.229535  2.271639
# 4   1.445387 -0.412052  0.490926  ...  1.210860 -0.588244 -0.587177
# 5  -0.397698  0.084474  2.003674  ...  0.830499  1.343693  2.116371
# 6  -0.886641 -0.045075 -0.655400  ... -0.112873 -0.912354 -0.615398
# 7   0.064075 -0.436889 -0.392977  ...  0.328947 -0.689680  1.149799
# 8  -1.497810  0.622814  0.898069  ...  0.327902  1.081714 -0.534499
# 9  -0.434044  0.458780 -0.892110  ...  1.942143  1.472891 -0.403072
# 10 -0.652776 -0.473739  2.298589  ... -0.496225 -1.011456 -0.476477
# 11  0.856700  3.418355  0.564668  ... -1.138441  0.439721 -0.439687
# 12  2.342768  0.128121 -1.052526  ...  0.549223  0.897027 -0.565636
# ...

# %%
#Scatter Plot
plt.figure(figsize=(13,8))
plt.scatter(x =df4['x1'], y = df4['x4'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("x1")
plt.ylabel("x4")
plt.show()

# %%
#barplot
plt.figure(figsize=(15,9))
plt.bar(x = df4['x1'], height =df4['x3'], width = 1.5, color="red")
plt.title("x1-x3 Plot", fontsize = 10)
plt.xlabel("x1")
plt.ylabel("x3")
plt.show()

# %%
#histogram
plt.figure(figsize=(13,9))
plt.hist(df4['x4'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("x4 Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'x2', y = 'x6', data = df4, hue = 'x1', palette='plasma')
plt.show()

# %%
#piechart
plt.figure(figsize=(8,8))
plt.pie(df4['x3'].value_counts(), autopct='%0.2f%%', labels = df4['x3'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %%
data5=make_regression(n_samples=100, n_features=7, n_informative=10, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, shuffle=True, coef=False, random_state=None)
data5
# Out:
# (array([[-4.32560590e-01,  7.72870996e-01, -5.75109011e-01,
#          -2.12244291e+00,  6.38717336e-02,  1.22791958e+00,
#           2.46950873e-01],
#         [ 3.12675040e-01, -4.02609153e-02,  1.26431386e+00,
#          -1.57775217e-01,  1.79205677e+00, -2.17662232e-01,
#           9.32530099e-01],
#         [ 1.21651333e+00,  1.89721052e-01,  4.82743979e-01,
#          -4.10300619e-01,  7.47988898e-01,  6.09388342e-01,
#           3.53322227e-01],
#         [-1.85006542e-02,  1.85256077e+00,  1.16334895e+00,
#          -1.91697591e+00,  8.24516219e-02, -5.28845104e-01,
#           9.73635960e-01],
#         [-1.72682130e+00, -3.52640767e-01, -1.77104444e-01,
#           1.63166813e-01, -4.86112365e-01,  2.04733532e+00,
#           1.38837504e+00],
#         [ 2.76076344e-02, -8.94694993e-01, -1.26635610e+00,
#          -4.04509408e-01, -7.93468955e-01, -5.13042776e-01,
#          -3.77079088e-01],
#         [ 6.45743237e-01, -2.23366381e-01, -9.08277310e-01,
# ...

# %%
df5 = pd.DataFrame(data5[0],columns=['x'+str(i) for i in range(0,7)])
df5
# Out:
#           x0        x1        x2        x3        x4        x5        x6
# 0  -0.432561  0.772871 -0.575109 -2.122443  0.063872  1.227920  0.246951
# 1   0.312675 -0.040261  1.264314 -0.157775  1.792057 -0.217662  0.932530
# 2   1.216513  0.189721  0.482744 -0.410301  0.747989  0.609388  0.353322
# 3  -0.018501  1.852561  1.163349 -1.916976  0.082452 -0.528845  0.973636
# 4  -1.726821 -0.352641 -0.177104  0.163167 -0.486112  2.047335  1.388375
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.512918 -1.237625 -1.472646  0.534769  1.236223  0.278627 -0.608305
# 96  0.762663  1.740348 -0.730301  1.250939  0.808442  1.900679 -2.311567
# 97 -0.929448 -1.172061  1.067711  0.726684  1.123147 -0.578059  1.912761
# 98  0.382350 -1.372141  1.401744  0.278115  1.028590  1.066715  1.682547
# 99  0.636423 -1.605329  0.463460  0.383028 -0.434097 -1.389429  0.019273
#
# [100 rows x 7 columns]

# %%
#Scatter Plot
plt.figure(figsize=(13,8))
plt.scatter(x =df5['x1'], y = df5['x2'], color='red')
plt.title("Scatter Plot", fontsize = 13)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
#barplot
plt.figure(figsize=(15,9))
plt.bar(x = df5['x1'], height =df5['x3'], width = 1.5, color="red")
plt.title("x1-x3 Plot", fontsize = 10)
plt.xlabel("x1")
plt.ylabel("x3")
plt.show()

# %%
#histogram
plt.figure(figsize=(13,9))
plt.hist(df5['x4'], bins = 15, color='red')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("x4 Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'x2', y = 'x6', data = df5, hue = 'x1', palette='plasma')
plt.show()

# %%
#piechart
plt.figure(figsize=(8,8))
plt.pie(df5['x3'].value_counts(), autopct='%0.2f%%', labels = df5['x3'].unique())
plt.show() 
plt.savefig('Pie.jpg')

# %% [markdown]
# Q5. Generate a datset df with make−regression function and create a dataframe.
# Compute the equation that governs the dataframe. Change the ‘noise’ and
# ‘bias’ parameters (without changing the other parameters) of the make −
# 3
# regression function and obtain 10 different dataframes df1,df2,df3,...,df10.
# Obtain the equations that govern each df, df1,df2,df3,...,df10. Prepare a new
# dataframe DF with a column for each coefficients of the equations (like
# w0,w1,w2 and so on) along with the columns for ‘noise’ and ‘bias’. Note that
# the rows of DF will be df, df1, df2,...,df10. If any column gets duplicated in
# DF, remove the duplicate. Draw a line plot for each of the coefficients in DF
# against noise. All the line-plots should be sub-plots in a figure.

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=10,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df1 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df1.head(10)
# Out:
#         age     salary
# 0 -0.359553 -19.955886
# 1  0.976639  21.339773
# 2  0.402342  11.556895
# 3 -0.813146 -16.342069
# 4 -0.887786 -35.700638
# 5  0.443863  27.995395
# 6 -0.977278 -56.323530
# 7  0.428332  17.610414
# 8  0.208275  21.451062
# 9 -0.311553 -22.352865

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=9,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df2 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df2.head(10)
# Out:
#         age     salary
# 0 -0.359553 -19.484281
# 1  0.976639  23.345329
# 2  0.402342  12.106550
# 3 -0.813146 -18.154424
# 4 -0.887786 -35.893499
# 5  0.443863  27.077193
# 6 -0.977278 -54.833419
# 7  0.428332  17.664879
# 8  0.208275  20.188740
# 9 -0.311553 -21.438109

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=8,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df3 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df3.head(10)
# Out:
#         age     salary
# 0 -0.359553 -19.012677
# 1  0.976639  25.350886
# 2  0.402342  12.656206
# 3 -0.813146 -19.966778
# 4 -0.887786 -36.086360
# 5  0.443863  26.158990
# 6 -0.977278 -53.343308
# 7  0.428332  17.719344
# 8  0.208275  18.926418
# 9 -0.311553 -20.523354

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=4,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df4 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df4.head(10)
# Out:
#         age     salary
# 0 -0.359553 -17.126260
# 1  0.976639  33.373112
# 2  0.402342  14.854830
# 3 -0.813146 -27.216197
# 4 -0.887786 -36.857804
# 5  0.443863  22.486179
# 6 -0.977278 -47.382862
# 7  0.428332  17.937203
# 8  0.208275  13.877129
# 9 -0.311553 -16.864333

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=6,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df5 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df5.head(10)
# Out:
#         age     salary
# 0 -0.359553 -18.069468
# 1  0.976639  29.361999
# 2  0.402342  13.755518
# 3 -0.813146 -23.591488
# 4 -0.887786 -36.472082
# 5  0.443863  24.322584
# 6 -0.977278 -50.363085
# 7  0.428332  17.828274
# 8  0.208275  16.401773
# 9 -0.311553 -18.693843

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=5.5,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df6= pd.DataFrame(data={'age':x.flatten(),'salary':y})
df6.head(10)
# Out:
#         age     salary
# 0 -0.359553 -17.833666
# 1  0.976639  30.364777
# 2  0.402342  14.030346
# 3 -0.813146 -24.497665
# 4 -0.887786 -36.568512
# 5  0.443863  23.863483
# 6 -0.977278 -49.618029
# 7  0.428332  17.855506
# 8  0.208275  15.770612
# 9 -0.311553 -18.236466

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=2.2,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df7 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df7.head(10)
# Out:
#         age     salary
# 0 -0.359553 -16.277372
# 1  0.976639  36.983114
# 2  0.402342  15.844211
# 3 -0.813146 -30.478435
# 4 -0.887786 -37.204953
# 5  0.443863  20.833413
# 6 -0.977278 -44.700661
# 7  0.428332  18.035240
# 8  0.208275  11.604949
# 9 -0.311553 -15.217773

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=8.7,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df8 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df8.head(10)
# Out:
#         age     salary
# 0 -0.359553 -19.342800
# 1  0.976639  23.946996
# 2  0.402342  12.271447
# 3 -0.813146 -18.698130
# 4 -0.887786 -35.951358
# 5  0.443863  26.801732
# 6 -0.977278 -54.386386
# 7  0.428332  17.681218
# 8  0.208275  19.810043
# 9 -0.311553 -21.163683

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=7.0,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df9 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df9.head(10)
# Out:
#         age     salary
# 0 -0.359553 -18.541073
# 1  0.976639  27.356442
# 2  0.402342  13.205862
# 3 -0.813146 -21.779133
# 4 -0.887786 -36.279221
# 5  0.443863  25.240787
# 6 -0.977278 -51.853196
# 7  0.428332  17.773809
# 8  0.208275  17.664095
# 9 -0.311553 -19.608599

# %%
x, y, coef = datasets.make_regression(n_samples=100,#number of samples
                                      n_features=1,#number of features
                                      n_informative=1,#number of useful features 
                                      noise=8.9,#bias and standard deviation of the guassian noise
                                      coef=True,#true coefficient used to generated the data
                                      random_state=0) #set for same data points for each run
df10 = pd.DataFrame(data={'age':x.flatten(),'salary':y})
df10.head(10)
# Out:
#         age     salary
# 0 -0.359553 -19.437121
# 1  0.976639  23.545885
# 2  0.402342  12.161516
# 3 -0.813146 -18.335659
# 4 -0.887786 -35.912785
# 5  0.443863  26.985372
# 6 -0.977278 -54.684408
# 7  0.428332  17.670325
# 8  0.208275  20.062508
# 9 -0.311553 -21.346634

# %% [markdown]
# Q6. Generate a dataset with make − classif ication function and create the respective dataframe df. Perform all the operations on the dataframe df as
# described in the notebook ’syntheticdata-classifictaion’ which is uploaded in
# the msteams

# %%
import pandas as pd

# %%
from sklearn.datasets import make_classification

variables, target = make_classification(n_samples=20,n_features=4)
df = pd.DataFrame(variables)
df['target'] = target
df
# Out:
#            0         1         2         3  target
# 0  -0.117627  0.804563 -0.203106 -0.031207       1
# 1   0.385079 -0.561973  0.040076 -0.181879       0
# 2  -0.868546 -1.182828  0.648563  0.746146       0
# 3  -1.472238 -0.401300  0.615735  1.044917       0
# 4   1.765323  1.726135 -1.113752 -1.423603       1
# 5  -0.872354  1.952194 -0.295587  0.318928       1
# 6   3.093230  2.767651 -1.874058 -2.459242       1
# 7  -0.856225  2.129221 -0.354394  0.283815       1
# 8  -0.590473 -1.519065  0.656521  0.605270       0
# 9   2.963038  2.914236 -1.874515 -2.391799       1
# 10 -0.260343 -2.554760  0.857923  0.525280       0
# 11  0.432272  0.733030 -0.366316 -0.391142       1
# 12 -0.378574  0.824205 -0.121344  0.141556       1
# 13 -0.609878  1.516340 -0.252347  0.202195       1
# 14  1.754166 -0.497517 -0.439415 -1.111262       0
# 15  1.093071 -0.197364 -0.307785 -0.707903       0
# 16  0.984629 -1.499689  0.121398 -0.456454       0
# ...

# %%
variables, target = make_classification(n_samples=20,n_features=4,flip_y=0.3)
print(variables)
print(target)
# Out:
# [[ 0.06788703 -1.8938846  -2.42404357  0.8901569 ]
#  [ 1.42481761  1.9790467   0.75203484 -0.85921241]
#  [ 0.71854441  1.50032867  1.00070591 -0.66853318]
#  [ 0.83584575 -0.21889034 -1.26607056  0.14216974]
#  [-2.66140341 -0.66385326  2.34760189  0.18461212]
#  [ 1.36990221  0.52148901 -0.98594113 -0.17922106]
#  [ 0.03457794 -2.33928205 -2.93545044  1.097163  ]
#  [-2.19417707 -2.81764016 -0.87350253  1.21543354]
#  [-1.52886592 -2.23469559 -0.94444542  0.9739998 ]
#  [-0.02522101 -0.98679936 -1.19088727  0.46093684]
#  [ 0.29540049  1.51905364  1.52771431 -0.69738011]
#  [-0.98858277 -0.6564412   0.36493128  0.26051448]
#  [-1.86991565 -2.46233548 -0.82000232  1.06442467]
#  [ 0.98995882  1.96186791  1.24857027 -0.8718009 ]
#  [ 0.81096932 -0.31554905 -1.35604106  0.18625617]
#  [-1.50404689 -0.09729015  1.6705086  -0.02580291]
#  [ 0.71268712  1.7931491   1.3699725  -0.80594349]
#  [ 0.78626066 -0.40292337 -1.43472419  0.22600253]
# ...

# %%
from itertools import combinations
lst_var=list(combinations(df.columns[:-1],2))
print(lst_var)
len_var=len(lst_var)
plt.figure(figsize=(18,10))
for i in range(1,len_var+1):
  plt.subplot(2,(len_var/2),i)
  var1=lst_var[i-1][0]
  var2=lst_var[i-1][1]
  plt.scatter(df[0],df[1],s=200,c=df['target'],edgecolor='k')
  plt.xlabel('x1',fontsize=14)
  plt.ylabel('x2',fontsize=14)
  plt.grid(True)
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# %% [markdown]
# Q7. Generate two datasets with make − classif ication function and create the
# respective dataframes df1,df2 with two input features, two classes and draw
# the scatter plot of x1 Vs x2 for df1 & df2 respectively such that
# (a) classes are easily separable by a line in the plot for df1
# (b) classes are not at all separable by a line in the plot for df1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
x, y = make_classification(n_samples=20,n_features=2,n_redundant=0,n_repeated=0,n_classes=2)
df = pd.DataFrame(x,columns=['x1','x2'])
df['y'] = y
df
# Out:
#           x1        x2  y
# 0   1.233567  1.024728  1
# 1  -0.365687  1.232275  1
# 2   0.690729  0.895612  1
# 3  -1.650832 -0.223434  1
# 4   0.095185 -1.399053  0
# 5  -1.489143 -2.058522  0
# 6  -0.363134  1.647663  1
# 7  -0.779211  1.746926  1
# 8  -1.710721 -0.078711  0
# 9   0.389309 -0.632886  0
# 10 -0.026968 -0.733896  0
# 11  0.799856 -1.366265  0
# 12  1.019792  0.789556  1
# 13 -0.375724 -0.513107  0
# 14 -1.019153  0.500770  1
# 15  1.204156 -0.772015  0
# 16 -0.124840  2.762751  1
# 17  1.170585 -0.758462  0
# 18  1.262974 -0.147005  0
# 19  3.250298  0.679521  1

# %%
plt.scatter(df['x1'],df['x2'],c=df['y'])
plt.show()

# %%
x, y = make_classification(n_samples=20,n_features=2,n_redundant=0,n_repeated=0,n_classes=2)
df2 = pd.DataFrame(x,columns=['x1','x2'])
df2['y'] = y
df2
# Out:
#           x1        x2  y
# 0   0.136058 -0.195723  0
# 1   2.705697  1.798221  1
# 2  -0.479498 -0.452237  0
# 3   1.356887  1.566898  1
# 4   0.137481 -0.412545  0
# 5  -0.424349  0.094347  0
# 6   0.476985  0.167074  0
# 7  -1.390036 -1.964832  0
# 8   1.158409 -0.892181  1
# 9  -2.163112 -2.953237  0
# 10  1.049864  1.420149  1
# 11  0.265371  0.999211  1
# 12 -0.919343  0.961342  0
# 13  0.064021 -3.018294  1
# 14  1.233721 -0.631135  1
# 15  0.705428  1.286167  1
# 16  2.244217  0.212952  1
# 17 -0.276057  0.065164  0
# 18 -1.278502 -1.472498  0
# 19  2.142302  0.156900  1

# %%
plt.scatter(df2['x1'],df2['x2'],c=df2['y'])
plt.show()

# %% [markdown]
# Q8.Genarate the dataset governed by the equation
#
# using gen regression symbolic and create the respective dataframe. Make
# scatter plots for each of the independent variable against y, in a single figure
# frame.

# %%
def symbolize(s):
    """
    Converts a a string (equation) to a SymPy symbol object
    """
    from sympy import sympify
    s1=s.replace('.','*')
    s2=s1.replace('^','**')
    s3=sympify(s2)
    
    return(s3)

# %%
def eval_multinomial(s,vals=None,symbolic_eval=False):
    """
    Evaluates polynomial at vals.
    vals can be simple list, dictionary, or tuple of values.
    vals can also contain symbols instead of real values provided those symbols have been declared before using SymPy
    """
    from sympy import Symbol
    sym_s=symbolize(s)
    sym_set=sym_s.atoms(Symbol)
    sym_lst=[]
    for s in sym_set:
        sym_lst.append(str(s))
    sym_lst.sort()
    if symbolic_eval==False and len(sym_set)!=len(vals):
        print("Length of the input values did not match number of variables and symbolic evaluation is not selected")
        return None
    else:
        if type(vals)==list:
            sub=list(zip(sym_lst,vals))
        elif type(vals)==dict:
            l=list(vals.keys())
            l.sort()
            lst=[]
            for i in l:
                lst.append(vals[i])
            sub=list(zip(sym_lst,lst))
        elif type(vals)==tuple:
            sub=list(zip(sym_lst,list(vals)))
        result=sym_s.subs(sub)
    
    return result

# %%
def flip(y,p):
    import numpy as np
    lst=[]
    for i in range(len(y)):
        f=np.random.choice([1,0],p=[p,1-p])
        lst.append(f)
    lst=np.array(lst)
    return np.array(np.logical_xor(y,lst),dtype=int)

# %%
def gen_regression_symbolic(m=None,n_samples=100,n_features=2,noise=0.0,noise_dist='normal'):
    """
    Generates regression sample based on a symbolic expression. Calculates the output of the symbolic expression 
    at randomly generated (drawn from a Gaussian distribution) points
    m: The symbolic expression. Needs x1, x2, etc as variables and regular python arithmatic symbols to be used.
    n_samples: Number of samples to be generated
    n_features: Number of variables. This is automatically inferred from the symbolic expression. So this is ignored 
                in case a symbolic expression is supplied. However if no symbolic expression is supplied then a 
                default simple polynomial can be invoked to generate regression samples with n_features.
    noise: Magnitude of Gaussian noise to be introduced (added to the output).
    noise_dist: Type of the probability distribution of the noise signal. 
    Currently supports: Normal, Uniform, t, Beta, Gamma, Poission, Laplace

    Returns a numpy ndarray with dimension (n_samples,n_features+1). Last column is the response vector.
    """
    
    import numpy as np
    from sympy import Symbol,sympify
    
    if m==None:
        m=''
        for i in range(1,n_features+1):
            c='x'+str(i)
            c+=np.random.choice(['+','-'],p=[0.5,0.5])
            m+=c
        m=m[:-1]
    
    sym_m=sympify(m)
    n_features=len(sym_m.atoms(Symbol))
    evals=[]
    lst_features=[]
    
    for i in range(n_features):
        lst_features.append(np.random.normal(scale=5,size=n_samples))
    lst_features=np.array(lst_features)
    lst_features=lst_features.T
    lst_features=lst_features.reshape(n_samples,n_features)
    
    for i in range(n_samples):
        evals.append(eval_multinomial(m,vals=list(lst_features[i])))
    
    evals=np.array(evals)
    evals=evals.reshape(n_samples,1)
    
    if noise_dist=='normal':
        noise_sample=noise*np.random.normal(loc=0,scale=1.0,size=n_samples)
    elif noise_dist=='uniform':
        noise_sample=noise*np.random.uniform(low=0,high=1.0,size=n_samples)
    elif noise_dist=='beta':
        noise_sample=noise*np.random.beta(a=0.5,b=1.0,size=n_samples)
    elif noise_dist=='Gamma':
        noise_sample=noise*np.random.gamma(shape=1.0,scale=1.0,size=n_samples)
    elif noise_dist=='laplace':
        noise_sample=noise*np.random.laplace(loc=0.0,scale=1.0,size=n_samples)
        
    noise_sample=noise_sample.reshape(n_samples,1)
    evals=evals+noise_sample
        
    x=np.hstack((lst_features,evals))
    
    return (x)

# %%
x=gen_regression_symbolic(m='(3*x1*x1*x1)+(2*x2*x2)+(x3)+1',n_samples=10,noise=0.1)
df=pd.DataFrame(x,columns=['y','x1','x2','x3'])
df
# Out:
#           y        x1        x2                 x3
# 0   3.07153  -6.85549   5.54147   187.465452446270
# 1  -10.3989  -2.49769   7.46831  -3352.42095527845
# 2   1.82048   0.90873  -5.53598   15.2158788579716
# 3   7.97427   7.37758   5.18185   1636.28431130990
# 4  0.113428   1.26831  0.197785   4.36642938457500
# 5  0.947693  0.901777  -2.56202   2.63784780056896
# 6   2.01218   11.7292  -5.47559   295.122309457168
# 7   5.35515   4.17496  -2.25811   494.532915756520
# 8   3.11789   10.8272  -12.5427   313.899521586287
# 9  0.186438    4.5904   1.94054   45.1031246141682

# %%
plt.scatter(df['x1'],df['x2'],s=200,c=df['y'],edgecolor='k')
plt.xlabel('x1',fontsize=14)
plt.ylabel('x2',fontsize=14)
plt.grid(True)

# %% [markdown]
# Q9. Genarate the dataset governed by the equation
# y = (x1)
# 2
# /3 + (x2)
# 4
# using ’gen classif ication symbolic’ and create the respective dataframe.
# Make scatter plots for each of the independent variable against y, in a single
# figure frame.

# %%
from sympy import sympify, Symbol, symbols
import numpy as np

def symbolize(s):
    """
    Converts a a string (equation) to a SymPy symbol object
    """
    s1=s.replace('.','*')
    s2=s1.replace('^','**')
    s3=sympify(s2)
    
    return(s3)

def eval_multinomial(s,vals=None,symbolic_eval=False):
    """
    Evaluates polynomial at vals.
    vals can be simple list, dictionary, or tuple of values.
    vals can also contain symbols instead of real values provided those symbols have been declared before using SymPy
    """
    sym_s=symbolize(s)
    sym_set=sym_s.atoms(Symbol)
    sym_lst=[]
    for s in sym_set:
        sym_lst.append(str(s))
    sym_lst.sort()
    if symbolic_eval==False and len(sym_set)!=len(vals):
        print("Length of the input values did not match number of variables and symbolic evaluation is not selected")
        return None
    else:
        if type(vals)==list:
            sub=list(zip(sym_lst,vals))
        elif type(vals)==dict:
            l=list(vals.keys())
            l.sort()
            lst=[]
            for i in l:
                lst.append(vals[i])
            sub=list(zip(sym_lst,lst))
        elif type(vals)==tuple:
            sub=list(zip(sym_lst,list(vals)))
        result=sym_s.subs(sub)
    
    return result

def flip(y,p):
    """
    Flips random bit (used to make a classification problem haredr)
    """
    lst=[]
    for i in range(len(y)):
        f=np.random.choice([1,0],p=[p,1-p])
        lst.append(f)
    lst=np.array(lst)
    return np.array(np.logical_xor(y,lst),dtype=int)


def gen_classification_symbolic(m=None,n_samples=100,n_features=2,flip_y=0.0):
    """
    Generates classification sample based on a symbolic expression.
    Calculates the output of the symbolic expression at randomly generated (Gaussian distribution) points and
    assigns binary classification based on sign.
    m: The symbolic expression. Needs x1, x2, etc as variables and regular python arithmatic symbols to be used.
    n_samples: Number of samples to be generated
    n_features: Number of variables. This is automatically inferred from the symbolic expression. So this is ignored 
                in case a symbolic expression is supplied. However if no symbolic expression is supplied then a 
                default simple polynomial can be invoked to generate classification samples with n_features.
    flip_y: Probability of flipping the classification labels randomly. A higher value introduces more noise and make
            the classification problem harder.
    Returns a numpy ndarray with dimension (n_samples,n_features+1). Last column is the response vector.
    """
    
    if m==None:
        m=''
        for i in range(1,n_features+1):
            c='x'+str(i)
            c+=np.random.choice(['+','-'],p=[0.5,0.5])
            m+=c
        m=m[:-1]
    sym_m=sympify(m)
    n_features=len(sym_m.atoms(Symbol))
    evals=[]
    lst_features=[]
    for i in range(n_features):
        lst_features.append(np.random.normal(scale=5,size=n_samples))
    lst_features=np.array(lst_features)
    lst_features=lst_features.T
    for i in range(n_samples):
        evals.append(eval_multinomial(m,vals=list(lst_features[i])))
    
    evals=np.array(evals)
    evals_binary=evals>0
    evals_binary=evals_binary.flatten()
    evals_binary=np.array(evals_binary,dtype=int)
    evals_binary=flip(evals_binary,p=flip_y)
    evals_binary=evals_binary.reshape(n_samples,1)
    
    lst_features=lst_features.reshape(n_samples,n_features)
    x=np.hstack((lst_features,evals_binary))
    
    return (x)


def gen_regression_symbolic(m=None,n_samples=100,n_features=2,noise=0.0,noise_dist='normal'):
    """
    Generates regression sample based on a symbolic expression. Calculates the output of the symbolic expression 
    at randomly generated (drawn from a Gaussian distribution) points
    m: The symbolic expression. Needs x1, x2, etc as variables and regular python arithmatic symbols to be used.
    n_samples: Number of samples to be generated
    n_features: Number of variables. This is automatically inferred from the symbolic expression. So this is ignored 
                in case a symbolic expression is supplied. However if no symbolic expression is supplied then a 
                default simple polynomial can be invoked to generate regression samples with n_features.
    noise: Magnitude of Gaussian noise to be introduced (added to the output).
    noise_dist: Type of the probability distribution of the noise signal. 
    Currently supports: Normal, Uniform, t, Beta, Gamma, Poission, Laplace

    Returns a numpy ndarray with dimension (n_samples,n_features+1). Last column is the response vector.
    """
    
    if m==None:
        m=''
        for i in range(1,n_features+1):
            c='x'+str(i)
            c+=np.random.choice(['+','-'],p=[0.5,0.5])
            m+=c
        m=m[:-1]
    
    sym_m=sympify(m)
    n_features=len(sym_m.atoms(Symbol))
    evals=[]
    lst_features=[]
    
    for i in range(n_features):
        lst_features.append(np.random.normal(scale=5,size=n_samples))
    lst_features=np.array(lst_features)
    lst_features=lst_features.T
    lst_features=lst_features.reshape(n_samples,n_features)
    
    for i in range(n_samples):
        evals.append(eval_multinomial(m,vals=list(lst_features[i])))
    
    evals=np.array(evals)
    evals=evals.reshape(n_samples,1)
    
    if noise_dist=='normal':
        noise_sample=noise*np.random.normal(loc=0,scale=1.0,size=n_samples)
    elif noise_dist=='uniform':
        noise_sample=noise*np.random.uniform(low=0,high=1.0,size=n_samples)
    elif noise_dist=='beta':
        noise_sample=noise*np.random.beta(a=0.5,b=1.0,size=n_samples)
    elif noise_dist=='Gamma':
        noise_sample=noise*np.random.gamma(shape=1.0,scale=1.0,size=n_samples)
    elif noise_dist=='laplace':
        noise_sample=noise*np.random.laplace(loc=0.0,scale=1.0,size=n_samples)
        
    noise_sample=noise_sample.reshape(n_samples,1)
    evals=evals+noise_sample
        
    x=np.hstack((lst_features,evals))
    
    return (x)

# %%
y,x1,x2 = symbols('y x1 x2')
exp = "(x1**2)/3 + x2**4"
reg_data = gen_regression_symbolic(exp,n_samples=20,n_features=3)
df = pd.DataFrame(reg_data,columns=[x1,x2,y])
df
# Out:
#          x1        x2                 y
# 0   2.30326 -0.105543  1.76846690050868
# 1  -1.27846   6.34215  1618.42008936967
# 2   5.51903  -6.28158  1567.10661916745
# 3  -12.7661   3.52044  207.923474009291
# 4    -1.512  -2.65772  50.6550278647401
# 5   5.17082   2.19603  32.1693306084440
# 6  -4.30517 -0.784692  6.55729166442929
# 7  -1.99556   4.25577  329.357333179234
# 8   3.34937   3.46229  147.438240191291
# 9  -1.70853  0.670167  1.17474034837968
# 10  2.25063  -10.0664  10269.8974838946
# 11  5.42651   -2.7499  66.9989730930342
# 12   1.0516   2.82179  63.7700542273775
# 13 -2.10042   5.60602  989.158528506602
# 14 -5.87529 -0.620895  11.6549657302189
# 15  5.66282  -1.40731  14.6116780033968
# 16  0.30102   5.81574  1144.01245242364
# 17 -2.26851   3.54702  160.005994899827
# 18  5.11366   1.33701  11.9119755480817
# 19  1.95851  -10.6031  12640.6911437464

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df[x1],df[y])
plt.scatter(df[x2],df[y])
plt.title("Scatter plot of variables wrt target")
plt.legend([x1,x2])
plt.show()

# %% [markdown]
# Q10.Generate a dataset with make − classif ication function and create the respective dataframe df with two classes and two input features such that the
# number of datapoints of each class are equal. Fine tune the same datset by
# giving different values for the parameter ‘class-sep’ (all the other parameters
# shall be the same) starting from 1.0 in a decreasing order of step of 0.01
# and make the scatter plot (involving the two input features) of each of the
# datasets obtained. Observe the plots and compute the maximum value of
# the ‘class-sep’ for which the classes are not separable by a line.

# %%
from sklearn.datasets import make_classification
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.scatterplot(ax=ax[0],x=df['x1'],y=df['y'],hue=df['y'])
ax[0].set_title('x1 vs y')
sns.scatterplot(ax=ax[1],x=df['x2'],y=df['y'],hue=df['y'])
ax[1].set_title('x2 vs y')
# Out:
# Text(0.5, 1.0, 'x2 vs y')

# %%
for i in range(0,110,10):
  i = i/100
  x, y = make_classification(n_samples=10,n_features=2,n_redundant=0,n_repeated=0,n_classes=2,class_sep=i,random_state=10)
  df = pd.DataFrame(x,columns=['x1','x2'])
  df['y'] = y
  fig, ax = plt.subplots(1,2, figsize=(10,5))
  fig.suptitle('Plot for class_sep='+str(i))
  fig, ax = plt.subplots(1,2, figsize=(10,5))
  sns.scatterplot(ax=ax[0],x=df['x1'],y=df['y'],hue=df['y'])
  ax[0].set_title('x1 vs y')
  sns.scatterplot(ax=ax[1],x=df['x2'],y=df['y'],hue=df['y'])
  ax[1].set_title('x2 vs y')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
